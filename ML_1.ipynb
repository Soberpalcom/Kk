# %% [markdown]
# *Sunil naunde *
# #**It3273**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# !pip install google-colab
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 10.7 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive

# %%
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
                # prompt: use pandas on above dataset

housing_data = pd.read_csv("/content/drive/MyDrive/ML/HousingData.csv")

# Explore the data
print(housing_data.head())
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296     15.3
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         B  LSTAT  MEDV
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90    NaN  36.2

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
housing_data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
#finding the null values
housing_data.isnull().sum()
# Out:
# CRIM       20
# ZN         20
# INDUS      20
# CHAS       20
# NOX         0
# RM          0
# AGE        20
# DIS         0
# RAD         0
# TAX         0
# PTRATIO     0
# B           0
# LSTAT      20
# MEDV        0
# dtype: int64

# %%
#remove the index

housing_data = housing_data.reset_index(drop=True)
housing_data
# Out:
#         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD  TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900    1  296
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93   0.0  0.573  6.030   NaN  2.5050    1  273
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
# find the max 0 value column

max_zeros_column1 = housing_data.columns[housing_data.eq(0).sum().argsort()[-1]]
max_zeros_column2 = housing_data.columns[housing_data.eq(0).sum().argsort()[-2]]
print(max_zeros_column1)
print(max_zeros_column2)
# Out:
# CHAS
# ZN

# %%
housing_data =housing_data.drop(['CHAS','ZN'],axis=1)

# %%
housing_data.columns
# Out:
# Index(['CRIM', 'INDUS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO',
#        'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
# compre crime and house price in matplotlib

plt.scatter(housing_data['CRIM'],housing_data['MEDV'])
plt.title('Crime Rate vs. Median House Price')
plt.xlabel('Crime Rate')
plt.ylabel('Median House Price')
plt.show()

# %%
plt.scatter(housing_data['AGE'],housing_data['MEDV'])
plt.title('AGE vs. Median House Price')
plt.xlabel("AGE")
plt.ylabel('Median House Price');
plt.show()

# %%
#Non Reatil Business acres per twon
plt.scatter(housing_data['INDUS'],housing_data['MEDV'])
plt.title('INDUS vs. Median House Price')
plt.xlabel("INDUS")
plt.ylabel('Median House Price');
plt.show()

# %%
#Avg of room per shelter
plt.scatter(housing_data['RM'],housing_data['MEDV'])
plt.title('RM vs. Median House Price')
plt.xlabel("RM")
plt.ylabel('Median House Price');
plt.show()

# %%
#Nitric Oxide
plt.scatter(housing_data['NOX'],housing_data['MEDV'])
plt.title('NOX vs. Median House Price')
plt.xlabel("NOX")
plt.ylabel('Median House Price');
plt.show()

# %%
#DIstance
plt.scatter(housing_data['DIS'],housing_data['MEDV'])
plt.title('DIS vs. Median House Price')
plt.xlabel("DIS")
plt.ylabel('Median House Price');
plt.show()

# %%
#DIstance
plt.scatter(housing_data['TAX'],housing_data['MEDV'])
plt.title('TAX vs. Median House Price')
plt.xlabel("TAX")
plt.ylabel('Median House Price');
plt.show()

# %%
#DIstance
plt.scatter(housing_data['B'],housing_data['MEDV'])
plt.title('B vs. Median House Price')
plt.xlabel("black")
plt.ylabel('Median House Price');
plt.show()

# %%
housing_data.columns
# Out:
# Index(['CRIM', 'INDUS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX', 'PTRATIO',
#        'B', 'LSTAT', 'MEDV'],
#       dtype='object')

# %%
# prompt: train and test perform


from sklearn.model_selection import train_test_split

X = housing_data.drop('MEDV', axis=1)  # Features
y = housing_data['MEDV']  # Target variable
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
from sklearn.linear_model import LinearRegression
model = LinearRegression()
print(X_train.head())
print(y_train.head())
# Out:
#          CRIM  INDUS    NOX     RM   AGE     DIS  RAD  TAX  PTRATIO       B  \
# 220   0.35809   6.20  0.507  6.951  88.5  2.8617    8  307     17.4  391.70
# 71    0.15876  10.81  0.413  5.961  17.5  5.2873    4  305     19.2  376.94
# 240   0.11329   4.93  0.428  6.897  54.3  6.3361    6  300     16.6  391.25
# 6     0.08829   7.87  0.524  6.012  66.6  5.5605    5  311     15.2  395.60
# 417  25.94060  18.10  0.679  5.304  89.1  1.6475   24  666     20.2  127.36
#
#      LSTAT
# 220   9.71
# 71    9.88
# 240  11.38
# 6    12.43
# 417  26.64
# 220    26.7
# 71     21.7
# 240    22.0
# 6      22.9
# 417    10.4
# Name: MEDV, dtype: float64

# %%
from sklearn.impute import SimpleImputer
imputer = SimpleImputer(missing_values=np.nan,strategy='mean')
X_train = imputer.fit_transform(X_train)
X_test  = imputer.fit_transform(X_test)

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
from sklearn import metrics
from sklearn.metrics import accuracy_score
mae = metrics.mean_absolute_error(y_test,y_pred)
mse = metrics.mean_squared_error(y_test,y_pred)

rmse = np.sqrt(mse)

# %%
print("MSE",mse)
print("MAE",mae)
print("RMSE",rmse)
# Out:
# MSE 36.633129500957445
# MAE 4.0391836328291095
# RMSE 6.052530834366517
